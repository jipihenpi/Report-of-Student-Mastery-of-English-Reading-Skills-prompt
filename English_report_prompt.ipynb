# %%
import requests


url = " "


headers = {
    "Content-Type": "application/json",
    "api-key": "YOUR_API_KEY"  
}

individual_data = {
    "A1.Direct information retrieval": 0.86,
    "A2.Overall comprehension": 0.53,
    "A3.Interpretation of concepts and relationships": 0.3,
    "A4.Indirect information inference": 0.22,
    "A5.Evaluation of the text structure": 0.61
}

individual_data_description = "\n".join([f"{key}: {value}" for key, value in individual_data.items()])

system_message = f"""You are an assistant who responds\
 in the style of Educational Assessor."""
user_message = f"""
Report template:
Data: 
Attribute---Mastery probability
A1. Direct information retrieval---0.99
A2. Overall comprehension within the text---0.97
A3. Interpretation of concepts and relationships---0.35
A4. Indirect information inference---0.95
A5. Evaluation of the text structure---0.51

The individual data shows that the student has high levels of proficiency in direct information retrieval (A1, 0.99), overall comprehension (A2, 0.97), and indirect information inference (A4, 0.95). These strengths indicate the student's ability to effectively identify key information, understand the main ideas and purposes of texts, and recognize and interpret implicit information such as tone, mood, and authorial intent. These skills enable the student to effectively engage with a variety of reading materials and extract essential details from them.
However, the student has not mastered the interpretation of concepts and relationships (A3, 0.35). Although they mastered the evaluation of the text structure (A5, 0.51), the probability is relatively low. These areas represent challenges for the student, as they may struggle to analyze and interpret the meaning of words, phrases, and ideas, as well as discern the relationships between various ideas and concepts. Furthermore, they may have difficulty recognizing and analyzing different parts of a text, such as the introduction, body, and conclusion, which could impact their understanding of how these components contribute to the overall meaning and purpose of the text. Addressing these weaknesses through targeted support and instruction can help students improve their reading abilities, allowing them to better comprehend and analyze complex texts. By focusing on these areas, the student will be better equipped to engage with a wide range of reading materials and derive deeper meaning from them.

Recommendations
Suggestions for individual students
 For the student, it would be beneficial to focus on improving their skills in interpretation of concepts and relationships, evaluation of the text structure, and indirect information inference. To improve these skills, the student could practice identifying the main idea of a text, making inferences about the author's intended meaning, analyzing the structure of a text, and drawing conclusions based on implied information.
	Suggestions for teachers
For teachers, they could scaffold the student's reading skills by providing activities that focus on interpretation, evaluation, and inference. For example, teachers could provide guided reading activities that help students identify the main idea of a text and make inferences about the author's intended meaning. Teachers could also provide activities that help students analyze the structure of a text and identify the author's purpose. Finally, teachers could provide activities that help students make connections between different parts of a text and draw conclusions based on implied information.
	Suggestions for parents
For parents, they can create a learning environment that supports the development of their child's reading skills by providing access to a variety of reading materials, including books, magazines, and newspapers. Parents can also encourage their child to read regularly and discuss what they have read. Additionally, parents can model good reading habits by reading themselves and discussing what they have read with their child. Finally, parents can provide opportunities for their child to practice interpretation, evaluation, and inference skills by asking them questions about what they have read and encouraging them to make connections between different parts of a text.
---
Based on the performance of students in English reading skills, create a detailed personal student report for them according to the report template mentioned above. The report should analyze the student's mastery of five reading skills:{individual_data}
Reflect on how these mastery probability demonstrate the student’s ability to effectively understand and engage with reading materials, identifying both their strong points and areas requiring improvement. Please assess the student's performance using the following guidelines: (1) Firstly, determine whether the student has achieved mastery of the skill. If the student's proficiency level is above 0.50, they are considered to have mastered the skill. Otherwise, they are considered to have not mastered it. Please categorize the mastered skills as strengths, and the non-mastered skills as areas that require improvement. (2) If all the skills are mastered or non-mastered, please categorize the skill as having either a high probability (i.e., strengths) or low probability of mastery (i.e., areas requiring improvements).

In the analysis, highlight how the student's proficiency in direct information retrieval, overall comprehension, and indirect information inference indicates their capacity to grasp key information, understand the core ideas of texts, and deduce implicit meanings, such as tone and authorial intent.

Discuss the implications of the student's lower mastery probability in the interpretation of concepts and relationships, and evaluation of the text structure. Explain how these challenges might affect their ability to analyze and interpret the meaning of words, phrases, ideas, and the organizational parts of texts, impacting their overall reading comprehension.

Provide recommendations tailored to the individual student, teachers, and parents:

For the student: suggest specific practices to enhance their interpretation of concepts and relationships, evaluation of the text structure, and indirect information inference.
For teachers: recommend instructional strategies and activities that can support the student in areas identified as needing improvement, focusing on interpretation, evaluation, and inference.
For parents: advise on creating a supportive reading environment and engaging practices that can bolster their child's reading skills, especially in critical thinking and text analysis.
Ensure the language and terminology used are consistent with educational assessment, English education, and pedagogical standards, providing a professional and insightful evaluation that can guide the student’s educational development.


"""


individual = {
    "messages": [ 
        {'role':'system', 
                 'content': system_message },
                {'role':'user',     
                 'content': user_message },
    ],
    "max_tokens": 1500,
    "temperature": 0.5,
    "frequency_penalty": 0,
    "presence_penalty": 0,
    "top_p": 0.95,
    "stop": None
}


response = requests.post(url, headers=headers, json=individual)


print(response.text)

# %%
class_data = {
    "Direct information retrieval": 0.82,
    "Overall comprehension ": 0.80,
    "Interpretation of concepts and relationships": 0.39,
    "Indirect information inference": 0.54,
    "Evaluation of the text structure": 0.49
}
class_data_description = "\n".join([f"{key}: {value}" for key, value in class_data.items()])

system_message = f"""You are an assistant who responds\
 in the style of Educational Assessor."""
user_message = f""" 
Report template:
Data:
Attribute---Mastery probability
A1. Direct information retrieval---0.88
A2. Overall comprehension within the text---0.82
A3. Interpretation of concepts and relationships---0.66
A4. Indirect information inference---0.63
A5. Evaluation of the text structure---0.69

The class mastered all five reading attributes. The probability for students to act well in direct information retrieval (A1, 0.88) and overall comprehension (A2, 0.82) is extremely high, indicating their proficiency in identifying key information and understanding the main ideas and purposes of texts. These strengths enable them to effectively extract essential details and make connections between different concepts within a text. 
However, although students also mastered the proportions of mastering the reading skills for interpretation of concepts and relationships (A3, 0.66), indirect information inference (A4, 0.63), and evaluation of the text structure (A5, 0.69), the probability are relatively lower. These areas represent aspects they could work on, as the students may struggle to analyze and interpret the meaning of words, phrases, and ideas and recognize and interpret implicit information such as tone, mood, and authorial intent. Furthermore, they may have difficulty analyzing and evaluating the structure and organization of texts, which could impact their understanding of how various text components contribute to the overall meaning and purpose. This pattern implies that the class may require additional support and targeted instruction in these domains to enhance their overall reading abilities, allowing them to better comprehend and analyze complex texts. 

Recommendations
Suggestions for teachers
In terms of identifying students who may need special attention, it would be helpful to look at individual mastery proportions of each skill. For example, students who scored significantly lower in the interpretation of concepts and relationships or indirect information inference may require additional support in these areas.
To improve the class's reading skills, it may be helpful to focus on activities that promote critical thinking and analysis of texts. For example, teachers could provide opportunities for students to engage in group discussions or debates about the texts they are reading. Additionally, teachers could incorporate technology such as online reading comprehension games or interactive reading activities to make learning more engaging and interactive.
Overall, it is important for teachers to provide a variety of instructional strategies and activities to support students with different learning needs and abilities. By focusing on improving weaker areas and providing targeted support, teachers can help their students develop stronger reading skills and perform better on assessments such as the PISA English reading test.
---
Based on the performance of students in English reading skills, create a detailed class report for them according to the report template mentioned above.  The report should include an analysis of the class's performance across five attributes: direct information retrieval, overall comprehension within the text, interpretation of concepts and relationships, indirect information inference, and evaluation of the text structure. The report should include an analysis of the class's performance across five reading skills:{class_data_description}

For each attribute, assign a mastery probability reflective of this new class's abilities, but tailored to their unique performance profile. These mastery probabilities should form the basis of your analysis, highlighting the class's strengths and areas for improvement. Please assess the student's performance using the following guidelines: (1) Firstly, determine whether the student has achieved mastery of the skill. If the student's proficiency level is above 0.50, they are considered to have mastered the skill. Otherwise, they are considered to have not mastered it. Please categorize the mastered skills as strengths, and the non-mastered skills as areas that require improvement. (2) If all the skills are mastered or non-mastered, please categorize the skill as having either a high probability (i.e., strengths) or a low probability of mastery (i.e., areas requiring improvements).

Discuss how the class's proficiency in direct information retrieval and overall comprehension suggests their capability to identify key information and grasp the core ideas and purposes of texts. Highlight how these strengths contribute to the class's ability to effectively extract essential details and make connections between concepts within texts.

Address the lower mastery proportions in the interpretation of concepts and relationships, indirect information inference, and evaluation of the text structure. Explore how these weaker areas may indicate challenges in analyzing and interpreting the meaning of words, phrases, ideas, and recognizing implicit information such as tone, mood, and authorial intent. Additionally, consider the implications of difficulties in analyzing and evaluating the structure and organization of texts on the students' understanding of how text components contribute to overall meaning and purpose.

Provide targeted recommendations for teachers, suggesting instructional strategies and activities designed to support students in improving their reading skills, particularly in the identified areas of weakness. Propose the use of group discussions, debates, technology-enhanced learning tools, and a variety of instructional methods to cater to different learning needs and abilities. Emphasize the importance of focusing on weaker areas and offering specific support to help students develop stronger reading skills and perform better in assessments.

Ensure the report uses educational assessment, pedagogy, and English education terminology accurately, providing a professional and insightful analysis to guide educational strategies and improve student outcomes in English literacy and comprehension.
"""

class_1 = {
    "messages": [ 
        {'role':'system', 
                 'content': system_message }, #set tone/behavior of assistant
                {'role':'user',    #prompts   
                 'content': user_message },
    ],
    "max_tokens": 1500,
    "temperature": 0.7,
    "frequency_penalty": 0,
    "presence_penalty": 0,
    "top_p": 0.95,
    "stop": None
}


response = requests.post(url, headers=headers, json=class_1)


print(response.text)

# %%
grade_data = {
    "Direct information retrieval": 0.95,
    "Overall comprehension": 0.82,
    "Interpretation of concepts and relationships": 0.89,
    "Indirect information inference": 0.69,
    "Evaluation of the text structure": 0.88
}
grade_data_description = "\n".join([f"{key}: {value}" for key, value in grade_data.items()])
data = {
    'A1': [0.95, 0.67, 0.99, 0.49, 0.98, 0.83, 0.95],
    'A2': [0.82, 0.82, 0.99, 0.51, 0.84, 0.64, 0.82],
    'A3': [0.87, 0.66, 0.86, 0.35, 0.59, 0.41, 0.89],
    'A4': [0.69, 0.69, 0.71, 0.26, 0.41, 0.68, 0.69],
    'A5': [0.88, 0.67, 0.91, 0.38, 0.61, 0.46, 0.88]
}
df = pd.DataFrame(data)
df.index = ["Class 1", "Class 2", "Class 3", "Class 4", "Class 5", "Class 6", "Class 7"]
data_description = "\n".join([f"{key}: {value}" for key, value in df.items()])
system_message = f"""You are an assistant who responds\
 in the style of Educational Assessor."""

user_message = f""" 
Grade prompt
Report template:
Data:
Attribute---Mastery probability
A1. Direct information retrieval---0.99
A2. Overall comprehension within the text---0.99
A3. Interpretation of concepts and relationships---0.87
A4. Indirect information inference---0.85
A5. Evaluation of the text structure---0.90

 	  Attribute   A1	A2	    A3	    A4	    A5
Class
Class 1			0.88	0.82	0.66	0.63	0.69
Class 2			0.99	0.95	0.9	    0.7  	0.9
Class 3			0.82	0.8	    0.39	0.54	0.49
Class 4			0.99	0.89	0.74	0.68	0.69
Class 5			0.98	0.92	0.79	0.66	0.82
Class 6			0.93	0.9	    0.56	0.6	    0.57
Class 7			0.85	0.83	0.97	0.99	0.98

The chart shows that the students in the sample have strong skills in direct information retrieval (A1) and overall comprehension (A2), with mastery proportions of 0.99 for each. This pattern implies that students are highly capable of understanding the main ideas and details of a text, as well as effectively extracting essential information and making connections between different concepts. 
Nonetheless, although the students also mastered interpreting concepts and relationships (A3, 0.87), indirect information inference (A4, 0.85), and evaluation of text structure (A5, 0.90), the probability are comparatively lower. These areas represent opportunities for growth, as students could further enhance their understanding of the deeper meaning and implications of a text by honing their skills in analyzing and interpreting the meanings of words, phrases, and ideas, recognizing and interpreting implicit information such as tone, mood, and authorial intent, and evaluating the structure and organization of texts to better comprehend how various text components contribute to the overall meaning and purpose.
There are variations in the scores of different classes in the same grade, implying the necessity for differentiated instruction. For example, Class 2 has the highest scores in all five reading skills, while Class 3 has the lowest scores in all five skills. This suggests that there may be differences in the quality of teaching or learning among the classes. For instance, Class 3 may need special attention as they have the lowest scores in all five reading skills. Class 1 and Class 7 also have relatively low scores in some skills and may benefit from extra support.

Recommendations
Suggestions for teachers
To improve reading skills, teachers can focus on developing students' skills in interpreting concepts and relationships, indirect information inference, and evaluation of text structure. This can be done by providing students with opportunities to analyze and discuss texts in class, asking open-ended questions that require higher-order thinking, and encouraging students to make connections between different parts of a text.
Suggestions for school leaders
To improve teaching and learning efficiency, schools can consider implementing the following strategies:
- Providing teachers with professional development opportunities to enhance their knowledge and skills in teaching reading.
- Using data to inform instructional decisions and target areas for improvement.
- Encouraging collaboration among teachers to share best practices and resources.
- Providing students with access to a variety of reading materials that are appropriate for their reading level and interests.
- Using technology to enhance reading instruction, such as online reading programs or digital reading materials.
---

Based on the performance of students in English reading skills, create a detailed grade report according to the provided template. The report should critically analyze the grade's and each class's performance across five key attributes: direct information retrieval (A1), overall comprehension within the text (A2), interpretation of concepts and relationships (A3), indirect information inference (A4), and evaluation of the text structure (A5).
Data:
    Grade data: {grade_data_description}
    Classes date: {data_description}

Instructions for Analysis:

Assign New Mastery Probabilities: Start by assigning new mastery probabilities for each of the five skills across different classes within the new grade. Ensure these probabilities reflect their unique performance profiles accurately. 

Critical Analysis of Mastery Probabilities:

For Grade-Level Analysis: Clearly state the overall mastery probabilities for the grade in each of the five reading skills. Pay close attention to the magnitude of these probabilities, identifying which areas show strengths (higher probabilities) and which show potential for growth (lower probabilities). Please assess the student's performance using the following guidelines: (1) Firstly, determine whether the student has achieved mastery of the skill. If the student's proficiency level is above 0.50, they are considered to have mastered the skill. Otherwise, they are considered to have not mastered it. Please categorize the mastered skills as strengths, and the non-mastered skills as areas that require improvement. (2) If all the skills are mastered or non-mastered, please categorize the skill as having either a high probability (i.e., strengths) or low probability of mastery (i.e., areas requiring improvements).

For Class-Level Comparison: Provide a detailed comparison of mastery probabilities among classes. Highlight differences with precision, especially noting any classes that significantly exceed or fall below the grade average in specific skills.

Address Logical Inconsistencies: When discussing the data, avoid logical inconsistencies. For instance, if a skill's mastery probability is high (e.g., A5, 0.88), it should be discussed as a strength or high proficiency area. Conversely, lower probabilities indicate areas needing improvement.

Provide Targeted Recommendations:

For Teachers: Suggest strategies focused on developing weaker areas identified through data analysis. Encourage the use of discussions, higher-order thinking questions, and exercises that promote text analysis and connection-making.

For School Leaders: Recommend actionable strategies such as professional development focused on reading instruction, the use of data to inform teaching, and enhancing access to diverse reading materials and technological resources.

Goal of the Report: Ensure the analysis is tailored to the new grade's data, providing a nuanced and accurate evaluation that guides effective educational strategies. This report should aim to enhance student outcomes in English literacy and comprehension by addressing both strengths and areas needing improvement as identified through careful analysis of the provided data.

"""

grade_a = {
    "messages": [ 
        {'role':'system', 
                 'content': system_message }, 
                {'role':'user',     
                 'content': user_message },
    ],
    "max_tokens": 2500,
    "temperature": 0.7,
    "frequency_penalty": 0,
    "presence_penalty": 0,
    "top_p": 0.95,
    "stop": None
}


response = requests.post(url, headers=headers, json=grade_a)

print(response.text)
